# %% [markdown]
# <a href="https://colab.research.google.com/github/QuangAnhDay/demo/blob/master/GPT-SoVITS-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 👇 Just Click the Play Button (Run) and Wait for Public Gradio Link

# %%
# @title Do Everything For Me and Launch Gradio
# %cd /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd /content/GPT-SoVITS

# !conda install -c conda-forge gcc gxx ffmpeg cmake
# !conda install pytorch==2.1.1 torchvision==0.16.1 torchaudio==2.1.1 pytorch-cuda=11.8 -c pytorch -c nvidia

# !pip install pyyaml  # This addresses the ModuleNotFoundError for yaml
# !pip install numba==0.56.4  # Trying to install numba separately to see if it resolves the issue

# !pip install -r requirements.txt

# !python webui.py
# Out:
# /content
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.
# /content/GPT-SoVITS
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# ...
#   Using cached numba-0.56.4.tar.gz (2.4 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Ignoring onnxruntime: markers 'platform_machine == "aarch64" or platform_machine == "arm64"' don't match your environment
# ...
#     GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth
#     GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth
# ...

# %%
# @title Do Everything For Me and Launch Gradio (Fixed)
# %cd /content

# Xóa thư mục cũ nếu có để tránh lỗi conflict
# !rm -rf GPT-SoVITS

# Clone lại repository
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd /content/GPT-SoVITS

# Cài đặt các thư viện hệ thống cần thiết (dùng apt thay vì conda trên Colab)
# !apt-get update && apt-get install -y gcc g++ ffmpeg cmake

# Cài đặt thư viện Python
# !pip install -r requirements.txt

# --- BƯỚC QUAN TRỌNG NHẤT ---
# Dùng lệnh này để tự động sửa file config.py, chuyển 'is_share = False' thành 'True'
# Điều này sẽ giúp tạo ra link gradio.live
# !sed -i 's/is_share = False/is_share = True/g' config.py

# Chạy WebUI
# !python webui.py
# Out:
# /content
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5816, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 5816 (delta 11), reused 4 (delta 4), pack-reused 5795 (from 3)
# Receiving objects: 100% (5816/5816), 14.08 MiB | 14.01 MiB/s, done.
# Resolving deltas: 100% (3335/3335), done.
# /content/GPT-SoVITS
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# ...

# %%
# @title Force Launch Gradio (Strong Method)
# %cd /content
# !rm -rf GPT-SoVITS
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd /content/GPT-SoVITS

# 1. Cài đặt môi trường cần thiết
# !apt-get update && apt-get install -y gcc g++ ffmpeg cmake
# !pip install -r requirements.txt

# 2. Xử lý "Mạnh tay": Can thiệp trực tiếp vào mã nguồn bằng Python
# Thay vì sửa config, ta sửa thẳng lệnh launch trong webui.py
import os

# Đọc file webui.py
with open("webui.py", "r", encoding="utf-8") as f:
    content = f.read()

# Thay thế các tham số launch để ép buộc share=True
# Tìm đoạn code khởi động và chèn share=True vào bất kể config nói gì
if "share=is_share" in content:
    content = content.replace("share=is_share", "share=True")
elif ".launch(" in content:
    # Nếu không tìm thấy biến is_share, chèn thẳng vào hàm launch
    content = content.replace(".launch(", ".launch(share=True, ")

# Ghi đè lại file webui.py
with open("webui.py", "w", encoding="utf-8") as f:
    f.write(content)

print(">>> Đã ép buộc chế độ Public Link thành công!")

# 3. Chạy WebUI
# !python webui.py
# Out:
# /content
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5816, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 5816 (delta 11), reused 4 (delta 4), pack-reused 5795 (from 3)
# Receiving objects: 100% (5816/5816), 14.08 MiB | 14.13 MiB/s, done.
# Resolving deltas: 100% (3335/3335), done.
# /content/GPT-SoVITS
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# ...
